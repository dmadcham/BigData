# %% [markdown]
# Primeros pasos con los pandas

# %%
import pandas as pd

# %%
# para cambiar el directorio de trabajo
# import os
# os.chdir("C:\\Users\\Vespertino\\Desktop\\combigdata\\pandasnumpy")

# %%
# datos de
# https://www.kaggle.com/datasets/vinicius150987/titanic3

# %%
# para google colab
#from google.colab import drive
#drive.mount('/content/drive')
# para google colab
#path = "/content/drive/My Drive/.../datos/"

# %%
path = "../datos/"
datos = pd.read_csv(path + "titanic-passengers.csv", sep = ";")

# %%
datos.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
datos.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
datos.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
len(datos)
# Out:
# 891

# %%
datos.shape
# Out:
# (891, 12)

# %%
datos.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
datos["Age"]
# es lo mismo que
datos.Age
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886     NaN
# 887    50.0
# 888    24.0
# 889    32.0
# 890    47.0
# Name: Age, Length: 891, dtype: float64

# %%
datos.head(3)
# Out:
#    PassengerId Survived  Pclass                        Name   Sex   Age  \
# 0          343       No       2  Collander, Mr. Erik Gustaf  male  28.0
# 1           76       No       3     Moen, Mr. Sigurd Hansen  male  25.0
# 2          641       No       3      Jensen, Mr. Hans Peder  male  20.0
#
#    SibSp  Parch  Ticket     Fare  Cabin Embarked
# 0      0      0  248740  13.0000    NaN        S
# 1      0      0  348123   7.6500  F G73        S
# 2      0      0  350050   7.8542    NaN        S

# %% [markdown]
# Seleccionar filas por posicion

# %%
datos[0:1]# no vale datos[0]
# Out:
#    PassengerId Survived  Pclass                        Name   Sex   Age  \
# 0          343       No       2  Collander, Mr. Erik Gustaf  male  28.0
#
#    SibSp  Parch  Ticket  Fare Cabin Embarked
# 0      0      0  248740  13.0   NaN        S

# %% [markdown]
# Mejor esta forma para evitar ambigüedades

# %%
datos.iloc[0]
# Out:
# PassengerId                           343
# Survived                               No
# Pclass                                  2
# Name           Collander, Mr. Erik Gustaf
# Sex                                  male
# Age                                  28.0
# SibSp                                   0
# Parch                                   0
# Ticket                             248740
# Fare                                 13.0
# Cabin                                 NaN
# Embarked                                S
# Name: 0, dtype: object

# %% [markdown]
# Solo algunas columnas

# %%
datos.iloc[0][['Age', 'Embarked']]
# Out:
# Age         28.0
# Embarked       S
# Name: 0, dtype: object

# %% [markdown]
# Recorrer un DataFrame fila a fila (solo lectura)

# %%
for index, row in datos.iterrows():
    print(index, row['PassengerId'], row['Survived'])
# Out:
# 0 343 No
# 1 76 No
# 2 641 No
# 3 568 No
# 4 672 No
# 5 105 No
# 6 576 No
# 7 382 Yes
# 8 228 No
# 9 433 Yes
# 10 135 No
# 11 294 No
# 12 755 Yes
# 13 595 No
# 14 127 No
# 15 434 No
# 16 378 No
# 17 533 No
# 18 666 No
# 19 225 Yes
# 20 83 Yes
# 21 130 No
# 22 544 Yes
# 23 815 No
# 24 273 Yes
# 25 464 No
# 26 588 Yes
# 27 661 Yes
# 28 90 No
# 29 115 No
# 30 373 No
# 31 729 No
# 32 528 No
# 33 537 No
# 34 727 Yes
# 35 31 No
# 36 477 No
# 37 431 Yes
# 38 664 No
# 39 44 Yes
# 40 347 Yes
# 41 891 No
# 42 100 No
# 43 72 No
# 44 198 No
# 45 307 Yes
# 46 704 No
# 47 51 No
# 48 399 No
# 49 563 No
# 50 186 No
# 51 483 No
# 52 445 Yes
# 53 839 Yes
# 54 75 Yes
# 55 697 No
# 56 794 No
# 57 117 No
# 58 686 No
# 59 453 No
# 60 152 Yes
# 61 639 No
# 62 538 Yes
# 63 718 Yes
# 64 279 No
# 65 397 No
# 66 877 No
# 67 887 No
# 68 220 No
# 69 241 No
# 70 231 Yes
# 71 581 Yes
# 72 52 No
# 73 298 No
# 74 486 No
# 75 840 Yes
# 76 85 Yes
# 77 39 No
# 78 288 No
# 79 59 Yes
# 80 119 No
# 81 613 Yes
# ...

# %% [markdown]
# Ahora creamos otro dataframe con los mismos datos usando el PassengerId como índice

# %%
datosIndice = pd.read_csv(path + "titanic-passengers.csv", sep = ";", index_col = "PassengerId")
datosIndice.head()
# Out:
#             Survived  Pclass                                         Name  \
# PassengerId
# 343               No       2                   Collander, Mr. Erik Gustaf
# 76                No       3                      Moen, Mr. Sigurd Hansen
# 641               No       3                       Jensen, Mr. Hans Peder
# 568               No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 672               No       1                       Davidson, Mr. Thornton
#
#                 Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# PassengerId
# 343            male  28.0      0      0      248740  13.0000    NaN        S
# 76             male  25.0      0      0      348123   7.6500  F G73        S
# 641            male  20.0      0      0      350050   7.8542    NaN        S
# 568          female  29.0      0      4      349909  21.0750    NaN        S
# 672            male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
datosIndice.loc[343]
# Out:
# Survived                            No
# Pclass                               2
# Name        Collander, Mr. Erik Gustaf
# Sex                               male
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          248740
# Fare                              13.0
# Cabin                              NaN
# Embarked                             S
# Name: 343, dtype: object

# %%
datosIndice.loc[343:641]
# Out:
#             Survived  Pclass                        Name   Sex   Age  SibSp  \
# PassengerId
# 343               No       2  Collander, Mr. Erik Gustaf  male  28.0      0
# 76                No       3     Moen, Mr. Sigurd Hansen  male  25.0      0
# 641               No       3      Jensen, Mr. Hans Peder  male  20.0      0
#
#              Parch  Ticket     Fare  Cabin Embarked
# PassengerId
# 343              0  248740  13.0000    NaN        S
# 76               0  348123   7.6500  F G73        S
# 641              0  350050   7.8542    NaN        S

# %%
datosIndice.iloc[0]
# Out:
# Survived                            No
# Pclass                               2
# Name        Collander, Mr. Erik Gustaf
# Sex                               male
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          248740
# Fare                              13.0
# Cabin                              NaN
# Embarked                             S
# Name: 343, dtype: object

# %%
datosIndice.loc[343]
# Out:
# Survived                            No
# Pclass                               2
# Name        Collander, Mr. Erik Gustaf
# Sex                               male
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          248740
# Fare                              13.0
# Cabin                              NaN
# Embarked                             S
# Name: 343, dtype: object

# %% [markdown]
# Tarifa media

# %%
datos.Fare.mean()
# Out:
# np.float64(29.699117647058824)

# %%
#datos.mean(numeric_only=True, axis = 1)
# Out:
# 0       45.888889
# 1       14.216667
# 2       76.506956
# 3       74.247222
# 4       95.777778
#           ...
# 886     92.879069
# 887     72.855556
# 888    129.222222
# 889     84.388889
# 890     35.111111
# Length: 891, dtype: float64

# %% [markdown]
# Seleccionamos solo los supervivientes

# %%
datos.Survived == "Yes"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %% [markdown]
# Número de supervivientes

# %%
(datos.Survived == "Yes").sum()
# Out:
# np.int64(342)

# %%
supervivientes = datos[datos.Survived == "Yes"]

# %%
supervivientes.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 880          548      Yes       2
# 882          418      Yes       2
# 885          187      Yes       3
# 888          342      Yes       1
# 889          633      Yes       1
#
#                                                 Name     Sex   Age  SibSp  \
# 880                       Padro y Manent, Mr. Julian    male   NaN      0
# 882                    Silven, Miss. Lyyli Karoliina  female  18.0      0
# 885  O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female   NaN      1
# 888                   Fortune, Miss. Alice Elizabeth  female  24.0      3
# 889                        Stahelin-Maeglin, Dr. Max    male  32.0      0
#
#      Parch         Ticket      Fare        Cabin Embarked
# 880      0  SC/PARIS 2146   13.8625          NaN        C
# 882      2         250652   13.0000          NaN        S
# 885      0         370365   15.5000          NaN        Q
# 888      2          19950  263.0000  C23 C25 C27        S
# ...

# %%
len(supervivientes)
# Out:
# 342

# %% [markdown]
# Porcentaje de supervivientes

# %%
100*len(supervivientes)/len(datos)
# Out:
# 38.38383838383838

# %% [markdown]
# Crear una nueva columna

# %%
datos['nueva1'] = 1
datos.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  nueva1
# 0    male  28.0      0      0      248740  13.0000    NaN        S       1
# 1    male  25.0      0      0      348123   7.6500  F G73        S       1
# 2    male  20.0      0      0      350050   7.8542    NaN        S       1
# 3  female  29.0      0      4      349909  21.0750    NaN        S       1
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S       1

# %% [markdown]
# A partir de otra columna

# %%
datos['nueva2'] = datos.Fare * 2
datos.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  nueva1  \
# 0    male  28.0      0      0      248740  13.0000    NaN        S       1
# 1    male  25.0      0      0      348123   7.6500  F G73        S       1
# 2    male  20.0      0      0      350050   7.8542    NaN        S       1
# 3  female  29.0      0      4      349909  21.0750    NaN        S       1
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S       1
#
#      nueva2
# 0   26.0000
# 1   15.3000
# ...

# %% [markdown]
# Crear una nueva columna como Survived pero con 1/0

# %%
supervivientes = [1 if x == "Yes" else 0 for x in datos.Survived]

# %%
datos["superv"] = supervivientes
datos.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# ...

# %% [markdown]
# Comprobar valores nulos

# %%
datos.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False   True  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
# ...

# %%
datos.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
datos.Age.isnull().sum()
# Out:
# np.int64(177)

# %% [markdown]
# Número de valores nulos en cada columna

# %%
datos.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# nueva1           0
# nueva2           0
# superv           0
# dtype: int64

# %% [markdown]
# Para seleccionar a los que no tienen edad nula

# %%
edadnonula = datos[~datos.Age.isnull()]

# %%
edadnonula.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  nueva1  \
# 0    male  28.0      0      0      248740  13.0000    NaN        S       1
# 1    male  25.0      0      0      348123   7.6500  F G73        S       1
# 2    male  20.0      0      0      350050   7.8542    NaN        S       1
# 3  female  29.0      0      4      349909  21.0750    NaN        S       1
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S       1
#
#      nueva2  superv
# 0   26.0000       0
# ...

# %% [markdown]
# Para rellenar los valores nulos

# %%
datos.Age.fillna(datos.Age.mean(), inplace = True)
# datos = datos.Age.fillna(datos.Age.mean())

# %%
datos.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# nueva1           0
# nueva2           0
# superv           0
# dtype: int64

# %% [markdown]
# Seleccionar filas

# %%
datos.query("Sex == 'male' & Age > 17")
# Out:
#      PassengerId Survived  Pclass                            Name   Sex  \
# 0            343       No       2      Collander, Mr. Erik Gustaf  male
# 1             76       No       3         Moen, Mr. Sigurd Hansen  male
# 2            641       No       3          Jensen, Mr. Hans Peder  male
# 4            672       No       1          Davidson, Mr. Thornton  male
# 5            105       No       3  Gustafsson, Mr. Anders Vilhelm  male
# ..           ...      ...     ...                             ...   ...
# 884          509       No       3        Olsen, Mr. Henry Margido  male
# 886          779       No       3         Kilgannon, Mr. Thomas J  male
# 887          435       No       1       Silvey, Mr. William Baird  male
# 889          633      Yes       1       Stahelin-Maeglin, Dr. Max  male
# 890          111       No       1  Porter, Mr. Walter Chamberlain  male
#
#            Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  nueva1  \
# ...

# %% [markdown]
# Para contarlos

# %%
datos.query("Sex == 'male' & Age > 17").PassengerId.count()
# Out:
# np.int64(519)

# %%
len(datos.query("Sex == 'male' & Age > 17"))
# Out:
# 519

# %% [markdown]
# Otra forma de seleccionar

# %%
# mujeres = datos[datos.Sex == 'female' & datos.Age > 10]
mujeres = datos[datos.Sex == 'female']
mujeres.head()
# Out:
#     PassengerId Survived  Pclass  \
# 3           568       No       3
# 7           382      Yes       3
# 9           433      Yes       2
# 11          294       No       3
# 12          755      Yes       2
#
#                                                  Name     Sex   Age  SibSp  \
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 7                         Nakid, Miss. Maria ("Mary")  female   1.0      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 11                                Haas, Miss. Aloisia  female  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
#
#     Parch      Ticket     Fare Cabin Embarked  nueva1    nueva2  superv
# 3       4      349909  21.0750   NaN        S       1   42.1500       0
# 7       2        2653  15.7417   NaN        C       1   31.4834       1
# 9       0  SC/AH 3085  26.0000   NaN        S       1   52.0000       1
# ...

# %% [markdown]
# Valores que aparecen en Pclass sin repetición

# %%
datos.Pclass.unique()
# Out:
# array([2, 3, 1])

# %% [markdown]
# Funciones de cadenas. Obtener el apellido de cada pasajero.

# %%
partidos = datos.Name.str.split(",", expand = True)
partidos.head()
# Out:
#            0                                    1
# 0  Collander                      Mr. Erik Gustaf
# 1       Moen                    Mr. Sigurd Hansen
# 2     Jensen                       Mr. Hans Peder
# 3    Palsson   Mrs. Nils (Alma Cornelia Berglund)
# 4   Davidson                         Mr. Thornton

# %% [markdown]
# Pone un número como nombre de columna

# %%
partidos[0]
# Out:
# 0             Collander
# 1                  Moen
# 2                Jensen
# 3               Palsson
# 4              Davidson
#              ...
# 886           Kilgannon
# 887              Silvey
# 888             Fortune
# 889    Stahelin-Maeglin
# 890              Porter
# Name: 0, Length: 891, dtype: object

# %% [markdown]
# Mejor cambiarlos por cadenas

# %%
partidos.columns = ["apellido", "nombre"]

# %%
partidos["apellido"]
# Out:
# 0             Collander
# 1                  Moen
# 2                Jensen
# 3               Palsson
# 4              Davidson
#              ...
# 886           Kilgannon
# 887              Silvey
# 888             Fortune
# 889    Stahelin-Maeglin
# 890              Porter
# Name: apellido, Length: 891, dtype: object

# %% [markdown]
# Para obtener parte de una cadena en todas las columnas

# %%
# los 3 primeros caracteres del nombre de cada fila
datos.Name.str[0:3]
# Out:
# 0      Col
# 1      Moe
# 2      Jen
# 3      Pal
# 4      Dav
#       ...
# 886    Kil
# 887    Sil
# 888    For
# 889    Sta
# 890    Por
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# Convertir tipo de dato de una columna
