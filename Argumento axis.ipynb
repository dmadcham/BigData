# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2], [3, 4],[5,6]])
df
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df.sum(axis = 0)
# Out:
# 0     9
# 1    12
# dtype: int64

# %%
df.sum(axis = 1)
# Out:
# 0     3
# 1     7
# 2    11
# dtype: int64
